# %% [markdown]
# ![%E0%B8%9B%E0%B8%81%20%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20python.png](attachment:%E0%B8%9B%E0%B8%81%20%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20python.png)

# %% [markdown]
# ## Python ภาษาคอมพิวเตอร์ที่มาแรงที่สุด

# %% [markdown]
# Python เป็นภาษาคอมพิวเตอร์ที่ถูกเผยแพร่โดย Guido Van Rossum เมื่อ 20 กุมภาพันธ์ 1991 และเติบโตจนกลายเป็นหนึ่งในภาษาที่ได้รับความนิยมมากที่สุด เนื่องจากถูกออกแบบโดยยึดหลักให้คนอ่านได้ง่ายเป็นหลักการที่สำคัญที่สุด ทำให้ได้คำสั่งที่ใช้งานง่าย คล้ายภาษาที่มนุษย์ใช้

# %% [markdown]
# ## Jupyter Notebook

# %% [markdown]
# โปแกรมที่เราใช้อยู่เรียกว่า Jupyter Notebook เป็นโปรแกรมที่ใช้เขียนคำสั่ง Python ในรูปแบบคล้ายไฟล์เอกสาร ที่สามารถเขียนคำสั่ง Python ทำสิ่งต่างๆ และใช้งานได้ง่ายซึ่งเหมาะกับการเรียนรู้สำหรับผู้เริ่มต้น รวมไปถึงการใช้งานด้าน Data

# %% [markdown]
# ## คำสั่ง print()

# %% [markdown]
# ตัวอย่างคำสั่งใช้แสดงผลตัวหนังสือ สำหรับการใช้งาน สามารถกดปุ่ม "Run" ที่อยู่แถบเครื่องมือด้านบนเพื่อให้โปรแกรมประมวลผลคำสั่งได้เลย

# %%
print('Welcome to Ultimate Python!')

# %% [markdown]
# ในคอร์สเราจะเรียนกันบน Jupyter Notebook ให้ทุกคนสามารถเรียนรู้ได้ง่ายยิ่งขึ้นทำให้ไม่ว่าใครก็สามารถเรียน Python และนำไปใช้งานจริงได้ทันที!

# %% [markdown]
# ## คำสั่งสำเร็จรูป

# %% [markdown]
# การประยุกต์ใช้งานรอบตัวสามารถทำได้ง่าย เนื่องจากมีเครื่องมือสำเร็จรูปที่ติดตั้ง และใช้งานได้ง่ายมากๆ เรียกว่า library

# %%
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.2 is available.
# You should consider upgrading via the 'c:\users\acer\anaconda3\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## ตัวอย่างการดึงข้อมูลเวปไซต์

# %% [markdown]
# เครื่องมือสำเร็จรูปที่เราเรียกใช้เพื่อดึงข้อมูลจากหน้าเวปผ่าน requests ที่รวบรวมคำสั่งที่ทำงานกับการเชื่อมต่อเวปไซต์เอาไว้

# %%
import requests
data = requests.get('https://www.pantip.com')
print(data.text)
# Out:
# <!DOCTYPE html><html lang="th"><head><link rel="icon" href="https://pantip.com/fav-icon.ico" type="image/x-icon"/><meta charSet="utf-8"/><meta name="google-site-verification" content="UaiArydZb5Bi28s5YgunZNSoObqXV97zA_OYbSuXAE8"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><link rel="preload" href="/static/fonts/material-design-icons/MaterialIcons-Regular.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="stylesheet" type="text/css" href="/static/v1.23/main.css"/><script>(function(w,d,s,l,i){w[l] = w[l] || []; w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# ...

# %% [markdown]
# ![%E0%B8%9B%E0%B8%81%20%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20python%20%281%29.png](attachment:%E0%B8%9B%E0%B8%81%20%E0%B8%A5%E0%B8%94%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%94%E0%B9%89%E0%B8%A7%E0%B8%A2%20python%20%281%29.png)
